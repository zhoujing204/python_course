# %% [markdown]
# # 06-Python函数

# %% [markdown]
# - 定义函数
# - 传递实参
# - 返回值
# - 传递列表参数
# - 传递任意数量的参数
# - 定义模块
# - 函数编写指南

# %% [markdown]
# ## 定义函数
# - def表示要定义一个函数
# - greet_user()是定义的函数名，必须要有圆括号
# - 函数名后面的后面是冒号，表示函数代码块开始
# - 函数体的代码块必须有缩进
# - 按照代码规范，第一句是函数的文档注释(docstring)

# %% [markdown]
# 形参和实参
# - 变量username是一个形参(parameter)。
# - 值’jesse’是一个实参（argument）。
# - 函数在被调用时，实参的值会被赋值给形参。

# %% [markdown]
# ### 形参和实参的值如果发生变化，会相互影响吗？

# %% [markdown]
# 两种参数类型：
# 1. 位置实参
# 2. 关键字实参

# %% [markdown]
# ## 位置实参
# 当函数有多个参数时，基于实参的顺序关联到对应位置的形参，这种关联方式称为位置实参。

# %% [markdown]
# ## 关键字实参
#
# - 关键字实参是传递给函数的名称-值对。直接在实参中将名称和值关联起来，因此向函数传递实参时不会混淆。
# - 关键字实参顺序不再重要。
# - 代码可读性更好。

# %% [markdown]
# ## 参数默认值
# - 编写函数时，可给每个形参指定默认值。
# - 在调用函数中给形参提供了实参时，Python将使用指定的实参值；否则，将使用形参的默认值。
# - 形参列表中的带有默认值的形参必须放在没有默认值的形参后面。

# %% [markdown]
# ## 函数返回值
# 当函数没有return语句时，函数默认返回None。

# %%
get_formatted_name('jimi', 'hendrix')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\workspaces\python_course\src\06-functions\06-functions copy.ipynb Cell 21 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/workspaces/python_course/src/06-functions/06-functions%20copy.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> get_formatted_name('jimi', 'hendrix')
#
# NameError: name 'get_formatted_name' is not defined

# %%
# Out:
# Jimi Hendrix
# John Lee Hooker

# %% [markdown]
# 函数返回字典

# %% [markdown]
# 函数返回多个值: 返回的是一个元组

# %%
# Out:
# First name: John, Last name: Hooker

# %% [markdown]
# ## 传递列表参数

# %%
# Out:
# Hello, Hannah!
# Hello, Ty!
# Hello, Margot!

# %% [markdown]
# 在函数中修改列表

# %%
# Out:
# Printing model: dodecahedron
# Printing model: robot pendant
# Printing model: iphone case
#
# The following models have been printed:
# dodecahedron
# robot pendant
# iphone case

# %% [markdown]
# ## 传递任意数量的位置实参： `*`

# %%
# Out:
# ('pepperoni',)
# ('mushrooms', 'green peppers', 'extra cheese')

# %% [markdown]
# 任意数量的位置实参必须放到普通位置实参后面

# %%
# Out:
# Making a 16-inch pizza with the following toppings:
# - pepperoni
#
# Making a 12-inch pizza with the following toppings:
# - mushroom
# - green peppers
# - extra cheese
#
# Making a 12-inch pizza with the following toppings:
# - mushroom
# - green peppers
# - extra cheese
# k, v = price, 16

# %% [markdown]
# ## `*` 操作符表示的是分解

# %%
# Out:
# 1 2 3 4 5
# h e l l o

# %%
# Out:
# 1 3
# 5
# [5]

# %% [markdown]
# ## 传递任意数量的关键字实参： `**`
# 你经常会看到形参名`**kwargs`，它让函数接受任意数量的关键字实参。

# %%
# Out:
# {'location': 'princeton', 'field': 'physics', 'first_name': 'albert', 'last_name': 'einstein'}

# %% [markdown]
# ## `**` 操作符表示的是分解字典

# %%
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# ## 导入模块
#
# - 在Python中，一个.py文件就是一个模块。
# - 只有builtin模块不需要导入，其他模块都需要导入。

# %% [markdown]
# ## 用于序列的内置函数
# - enumerate
# - zip

# %% [markdown]
# 我们经常在循环的时候需要用到序列的索引

# %% [markdown]
# 这时候我们可以用内置函数enumerate,这样就不需要自己定义一个index来记录索引了

# %%
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': None}

# %% [markdown]
# zip函数：将多个序列压缩成一个序列

# %%
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd'), (5, 'e')]
# []

# %%
# Out:
# {1: 'a', 2: 'b', 3: 'c', 4: 'd', 5: 'e'}

# %% [markdown]
# zip函数可以接受任意多个序列，然后返回一个元组(tuple)的列表

# %%
# Out:
# [(1, 'a', 'A'), (2, 'b', 'B'), (3, 'c', 'C'), (4, 'd', 'D'), (5, 'e', 'E')]

# %% [markdown]
# 矩阵转置

# %%
# Out:
# [1, 2, 3] [4, 5, 6] [7, 8, 9]
# [(1, 4, 7), (2, 5, 8), (3, 6, 9)]

# %% [markdown]
# ## 判断数独是否合法
#
# ![Sudoku validation](./img/2023-09-17-07-48-35.png)

# %%
from itertools import product

def validate_sudoku(board):

    return True

# %%
board1 =[[8,4,7,2,6,5,1,9,3],
        [1,3,6,7,9,8,2,4,5],
        [9,5,2,1,4,3,8,6,7],
        [4,2,9,6,7,1,5,3,8],
        [6,7,8,5,3,2,9,1,4],
        [3,1,5,4,8,9,7,2,6],
        [5,6,4,9,1,7,3,8,2],
        [7,8,1,3,2,4,6,5,9],
        [2,9,3,8,5,6,4,7,1]]  # True
print(validate_sudoku(board1))

board2 =[[8,4,7,2,6,5,1,0,3],
        [1,3,6,7,0,8,2,4,5],
        [0,5,2,1,4,3,8,6,7],
        [4,2,0,6,7,1,5,3,8],
        [6,7,8,5,3,2,0,1,4],
        [3,1,5,4,8,0,7,2,6],
        [5,6,4,0,1,7,3,8,2],
        [7,8,1,3,2,4,6,5,0],
        [2,0,3,8,5,6,4,7,1]] # a valid board, but with 0 instead of 9
print(validate_sudoku(board2))
# Out:
# True
# False

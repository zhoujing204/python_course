# %% [markdown]
# # 04-if语句、Python字典、用户输入和while循环

# %% [markdown]
# ## if语句

# %%
cars = ['audi', 'bmw', 'subaru', 'toyota']
for car in cars:
    if car == 'bmw':
        print(car.upper())
    else:
        print(car.title())
# Out:
# Audi
# BMW
# Subaru
# Toyota

# %% [markdown]
# ### 条件测试
# if语句的核心是一个值为`True`或`False`的表达式
# - `==` 和 `is` 操作符的区别
# - 检测是否不相等
# - 大于、小于
# - 使用and检查多个条件
# - 使用or检查多个条件
# - 检查是否在列表中： in 操作符
# - 检查某个数是不是为0，不为0表示True，0表示False

# %%
car = 'bmw'
car == 'bmw'
# Out:
# True

# %% [markdown]
# `==`操作符比较两个变量的值是否相等

# %%
print(cars == cars[:])
print([1, 2, 3] == list(range(1, 4)))
print((1, 2, 3) == tuple(range(1, 4)))
print(1 == 1.0)
print(1 == True)     # True == 1
print(0 == False)    # False == 0
# Out:
# True
# True
# True
# True
# True
# True

# %% [markdown]
# 如果两个变量使用`id()`函数返回相同的结果，对他们使用`is`会返回`True`（充分必要条件）

# %%
cars = ['audi', 'bmw', 'subaru', 'toyota']
print(cars == cars[:])
print(cars is cars[:])

my_cars = cars
print(my_cars == cars)
print(my_cars is cars)
# Out:
# True
# False
# True
# True

# %%
x = 1
y = 1.0
print(x == y)
print(x is y)
# Out:
# True
# False

# %% [markdown]
# 检测是否不相等：`!=`

# %%
requested_toppings = 'mushrooms'
if requested_toppings != 'anchovies':
    print("Hold the anchovies!")
# Out:
# Hold the anchovies!

# %% [markdown]
# 检测不是同一个对象：`is not`

# %%
cars2 = cars[:]
print(cars2 is not cars)
# Out:
# True

# %% [markdown]
# 数值比较大小：`>`, `>=`, `<`, `<=`

# %%
age = 18
print(age > 18)
print(age >= 18)
print(age < 18)
print(age <= 18)
# Out:
# False
# True
# False
# True

# %% [markdown]
# 使用`and`和`or`检查多个条件

# %%
age_0 = 22
age_1 = 18
print(age_0 >= 21 and age_1 >= 21)
print(age_0 >= 21 or age_1 >= 21)
# Out:
# False
# True

# %% [markdown]
# 使用`in`操作符检查特定值是否包含在列表中,`not in`检查特定值是否不包含在列表中

# %%
requested_toppings = ['mushrooms', 'onions', 'pineapple']
print('mushrooms' in requested_toppings)
print('onions' not in requested_toppings)
# Out:
# True
# False

# %% [markdown]
# 简化多个条件

# %%
name = 'Jack'
pwd = '1234'
print((name, pwd) == ('Jack', '1234'))
# Out:
# True

# %%
x = 1
print(x == 0 or x == 1)
print(x in (0, 1))
# Out:
# True
# True

# %% [markdown]
# `if-else`语句

# %%
age = 17
if age >= 18:
    print("You are old enough to vote!")
    print("Have you registered to vote yet?")
else:
    print("Sorry, you are too young to vote.")
    print("Please register to vote as soon as you turn 18!")
# Out:
# Sorry, you are too young to vote.
# Please register to vote as soon as you turn 18!

# %% [markdown]
# `if...else`表达式

# %%
a, b = 10, 20
c = a if a else b
print(c)
# Out:
# 10

# %% [markdown]
# `if-elif-else`语句

# %%
age = 12
if age < 4:
    print("Your admission cost is $0.")
elif age < 18:
    print("Your admission cost is $5.")
else:
    print("Your admission cost is $10.")
# Out:
# Your admission cost is $5.

# %% [markdown]
# 判断列表是否为空

# %%
requested_toppings = []

if requested_toppings:
    for topping in requested_toppings:
        print(f"Adding {topping}.")
    print("\nFinished making your pizza!")
else:
    print("Are you sure you want a plain pizza?")
# Out:
# Finished making your pizza!

# %% [markdown]
# 判断字符串是否为空

# %%
msg = ''

if msg:
    print("msg is not empty")
else:
    print("msg is empty")
# Out:
# msg is empty

# %% [markdown]
# 判断数值是否为0

# %%
x = 0.000

if x:
    print("x is not zero")
else:
    print("x is zero")
# Out:
# x is zero

# %%
a = 0 + 0.00j
print(a == 0)
if a:
    print("a is not zero")
else:
    print("a is zero")
# Out:
# True
# a is zero

# %% [markdown]
# ## 字典

# %%
alien_0 = {'color': 'green', 'points': 5}
print(alien_0['color'])
print(alien_0['points'])
# Out:
# green
# 5

# %% [markdown]
# 添加键值对

# %%
alien_0['x_position'] = 0
alien_0['y_position'] = 25
print(alien_0)
# Out:
# {'color': 'green', 'points': 5, 'x_position': 0, 'y_position': 25}

# %% [markdown]
# 创建空字典

# %%
alien_0 = {}
print(alien_0)
alien_0['color'] = 'green'
alien_0['points'] = 5
print(alien_0)
# Out:
# {}
# {'color': 'green', 'points': 5}

# %% [markdown]
# 修改字典中的值

# %%
alien_0['color'] = 'yellow'
print(f"The alien is now {alien_0['color']}.")
# Out:
# The alien is now yellow.

# %% [markdown]
# 删除键值对

# %%
del alien_0['points']
print(alien_0)
# Out:
# {'color': 'yellow'}

# %% [markdown]
# 由类似对象组成的字典

# %%
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'python',
}

language = favorite_languages['sarah'].title()
print(f"Sarah's favorite language is {language}.")
# Out:
# Sarah's favorite language is C.

# %% [markdown]
# 使用get()方法来返回默认值

# %%
alien_0 = {'color': 'green', 'speed': 'slow'}
print(alien_0['points'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\workspaces\python_course\src\04-dicionaries-user-input-and-while-loops\04-dicionaries-user-input-and-while-loops.ipynb Cell 49 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/workspaces/python_course/src/04-dicionaries-user-input-and-while-loops/04-dicionaries-user-input-and-while-loops.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> alien_0 = {'color': 'green', 'speed': 'slow'}
# ----> <a href='vscode-notebook-cell:/d%3A/workspaces/python_course/src/04-dicionaries-user-input-and-while-loops/04-dicionaries-user-input-and-while-loops.ipynb#Y102sZmlsZQ%3D%3D?line=1'>2</a> print(alien_0['points'])
#
# KeyError: 'points'

# %%
print(alien_0.get('points', 'No point value assigned.'))
# Out:
# No point value assigned.

# %% [markdown]
# 遍历字典键值对

# %%
user_0 = {
    'username': 'efermi',
    'first': 'enrico',
    'last': 'fermi',
}

for key, value in user_0.items():
    print(f'\nKey:{key}')
    print(f'Value:{value}')
# Out:
# Key:username
# Value:efermi
#
# Key:first
# Value:enrico
#
# Key:last
# Value:fermi

# %%
for name, language in favorite_languages.items():
    print(f"{name.title()}'s favorite language is {language.title()}.")
# Out:
# Jen's favorite language is Python.
# Sarah's favorite language is C.
# Edward's favorite language is Ruby.
# Phil's favorite language is Python.

# %% [markdown]
# 遍历字典的键

# %%
for name in favorite_languages.keys():
    print(name.title())
# Out:
# Jen
# Sarah
# Edward
# Phil

# %%
print(sorted(favorite_languages.keys()))
# Out:
# ['edward', 'jen', 'phil', 'sarah']

# %% [markdown]
# 遍历字典中的值

# %%
for language in favorite_languages.values():
    print(language.title())
# Out:
# Python
# C
# Ruby
# Python

# %% [markdown]
# 使用set()函数剔除重复项

# %%
print(set(favorite_languages.values()))
# Out:
# {'ruby', 'c', 'python'}

# %% [markdown]
# ### set集合数据结构
# - 不包含重复的元素
# - 和dict同样使用`{  }`来定义, 但不是键值对
# - 空的集合用`set()`表示, `{}`表示的是空的字典

# %% [markdown]
# 嵌套的数据结构： 字典列表

# %%
alien_0 = {'color': 'green', 'points': 5}
alien_1 = {'color': 'yellow', 'points': 10}
alien_2 = {'color': 'red', 'points': 15}

aliens = [alien_0, alien_1, alien_2]
aliens
# Out:
# [{'color': 'green', 'points': 5},
#  {'color': 'yellow', 'points': 10},
#  {'color': 'red', 'points': 15}]

# %% [markdown]
# 在字典中存储列表

# %%
pizza = {
    'crust': 'thick',
    'toppings': ['mushrooms', 'extra cheese'],
}

print(pizza)
# Out:
# {'crust': 'thick', 'toppings': ['mushrooms', 'extra cheese']}

# %%
favorite_languages = {
    'jen': ['python', 'ruby'],
    'sarah': ['c'],
    'edward': ['ruby', 'go'],
    'phil': ['python', 'haskell'],
}

print(favorite_languages)
# Out:
# {'jen': ['python', 'ruby'], 'sarah': ['c'], 'edward': ['ruby', 'go'], 'phil': ['python', 'haskell']}

# %% [markdown]
# 在字典中存储列表

# %%
users = {
    'aeinstein': {
        'first': 'albert',
        'last': 'einstein',
        'location': 'princeton',
        },
    'mcurie': {
        'first': 'marie',
        'last': 'curie',
        'location': 'paris',
        },
}

print(users)
# Out:
# {'aeinstein': {'first': 'albert', 'last': 'einstein', 'location': 'princeton'}, 'mcurie': {'first': 'marie', 'last': 'curie', 'location': 'paris'}}

# %% [markdown]
# ### 用户输入
#
# - 使用input函数，用户可以在控制台进行输入。
# - input()接受一个参数，要向用户显示的提示（prompt）或说明。
# - input接受用户的输入后，将返回包含用户输入内容的字符串
# - 用户输入的数字也是`str`类型，进行数值相关操作时必须转换成对应的数值类型，例如使用`int()`函数或`float()`函数

# %%
message = input("Tell me something, and I will repeat it back to you: ")

# %%
print(message)
# Out:
# Hello

# %%
age = input("How old are you?")

# %%
age >= 18
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\workspaces\python_course\src\04-dicionaries-user-input-and-while-loops\04-dicionaries-user-input-and-while-loops.ipynb Cell 74 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/workspaces/python_course/src/04-dicionaries-user-input-and-while-loops/04-dicionaries-user-input-and-while-loops.ipynb#Y140sZmlsZQ%3D%3D?line=0'>1</a> age >= 18
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
int(age) >= 18
# Out:
# True

# %% [markdown]
# ### while循环

# %%
unconfirmed_users = ['alice', 'brian', 'candace']
confirmed_users = []

while unconfirmed_users:
    current_user = unconfirmed_users.pop()
    print(f"Verifying user: {current_user.title()}")
    confirmed_users.append(current_user)
    
print("\nThe following users have been confirmed:")
for confirmed_user in confirmed_users:
    print(confirmed_user.title())
# Out:
# Verifying user: Candace
# Verifying user: Brian
# Verifying user: Alice
#
# The following users have been confirmed:
# Candace
# Brian
# Alice

# %% [markdown]
# ### `match/case`语句
# - Python 3.10引入了新的`match/case`语句
# - `match/case`语句类似于C和Java中的`switch/case`语句，但更加强大,可以匹配更多的模式
# - 具体可以参考官方文档[PEP 636 – Structural Pattern Matching:
# Tutorial](https://peps.python.org/pep-0636/)
# - 或者参考《Fluent Python》一书中这些小节：
#   - Pattern Matching with Sequences
#   - Pattern Matching with Mapping
#   - Pattern Matching Class Instances
#   - Pattern Matching in lis.py: A Case Study

# %%
# 输入格式为: action object
# 例如： 
# move north
# get sword
# attack orc
command = input("What are you doing next? ")

# %%
match command.split():
    case ["quit"]:
        print("Goodbye!")
        print("quit_game()")
    case ["look"]:        
        print("current_room.describe()")
    case ["get", obj]:
        print(f"Get a {obj}")
    case ["go", direction]:
        print(f"Go to the {direction}")
    case _:
        print("Unknown command.")
# Out:
# Go to the south

# %% [markdown]
# ### 习题：从两个列表来创建字典
# 有两个列表，可能有不同的长度。第一个由 keys 组成，第二个由 values 组成。
#
# 写一个函数 createDict(keys, values) ，返回由 keys 和 values 创建的 dictionary。如果没有足够的值，其余的键应该有一个 None 值。如果没有足够的键，就忽略其余的值。
#
# Examples:
# ```python
# keys = ['a', 'b', 'c', 'd']
# values = [1, 2, 3]
# createDict(keys, values) # {'a': 1, 'b': 2, 'c': 3, 'd': None}
#
# keys = ['a', 'b', 'c']
# values = [1, 2, 3, 4]
# createDic(keys, values) # {'a': 1, 'b': 2, 'c': 3}
# ```

# %%
def createDict(keys, values):
    return {
        keys[i]: values[i] if i < len(values) else None
        for i in range(len(keys))
    }

# %%
keys = ['a', 'b', 'c']
values = [1, 2, 3, 4]
createDict(keys, values) # {'a': 1, 'b': 2, 'c': 3}
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
keys = ['a', 'b', 'c', 'd']
values = [1, 2, 3]
createDict(keys, values) # {'a': 1, 'b': 2, 'c': 3, 'd': None}
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': None}

# %% [markdown]
# ### 习题： 括号匹配
#
# 写一个函数，接收一串括号，并确定括号的顺序是否有效。如果字符串是有效的，它应该返回True，如果是无效的，它应该返回False。
#
# 例如：
# ```
# "(){}[]" => True
# "([{}])" => True
#  "(}" => False
#  "[(])" => False
# "[({})](]" => False
# ```

# %%
def match_brackets(s):
    stack = []
    brackets = {'(': ')', '[': ']', '{': '}'}
    for c in s:
        if c in brackets:
            stack.append(c)
        elif c in brackets.values():
            if not stack or brackets[stack.pop()] != c:
                return False
    return not stack
